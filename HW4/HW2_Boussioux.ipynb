# %%
using JuMP
using Gurobi
using DataFrames
using CSV
using LinearAlgebra
using Plots
using Statistics

# %%
model = read_from_file("markshare2.mps")
set_optimizer(model, Gurobi.Optimizer)
# Out:
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27

# %%
#Time ablation experiment

# %%
set_optimizer_attribute(model, "TimeLimit", 180)
#set_optimizer_attribute(model, "VarBranch", 0)
optimize!(model)
objective_value(model)
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 74 columns and 434 nonzeros
# Model fingerprint: 0x648e74a7
# Variable types: 14 continuous, 60 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+03, 2e+03]
# Presolved: 7 rows, 67 columns, 427 nonzeros
#
# Continuing optimization...
#
#  3575524 157199 infeasible   57        16.00000    0.00000   100%   3.1   60s
#  3836983 168103    0.00000   46    7   16.00000    0.00000   100%   3.1   65s
#  4093488 176004 infeasible   59        16.00000    0.00000   100%   3.1   70s
#  4345436 181256    0.00000   49    7   16.00000    0.00000   100%   3.1   75s
#  4581621 190185    0.00000   39    7   16.00000    0.00000   100%   3.1   80s
# ...

# %%
set_optimizer_attribute(model, "TimeLimit", 300)
#set_optimizer_attribute(model, "VarBranch", 0)
optimize!(model)
objective_value(model)
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 74 columns and 434 nonzeros
# Model fingerprint: 0x648e74a7
# Variable types: 14 continuous, 60 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+03, 2e+03]
# Presolved: 7 rows, 67 columns, 427 nonzeros
#
# Continuing optimization...
#
#  36030570 279803    0.00000   18    4 11.0000000    0.00000   100%   2.9  849s
#  36153335 187087    0.00000   55    2 11.0000000    0.00000   100%   2.9  852s
#  36276100 261059    0.00000   10    7 11.0000000    0.00000   100%   2.9  855s
#  36521630 161306    0.00000   23    4 11.0000000    0.00000   100%   2.9  861s
#  36767160 194624    0.00000   20    5 11.0000000    0.00000   100%   2.9  867s
# ...

# %%
set_optimizer_attribute(model, "TimeLimit", 450)
#set_optimizer_attribute(model, "VarBranch", 0)
optimize!(model)
objective_value(model)
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 74 columns and 434 nonzeros
# Model fingerprint: 0x648e74a7
# Variable types: 14 continuous, 60 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+03, 2e+03]
# Presolved: 7 rows, 67 columns, 427 nonzeros
#
# Continuing optimization...
#
#  48152897 225582    0.00000   42    5 11.0000000    0.00000   100%   2.9 1154s
#  48275662 319252    0.00000   54    8 11.0000000    0.00000   100%   2.9 1157s
#  48521192  5462    0.00000   54    3 11.0000000    0.00000   100%   2.9 1162s
#  48643957 421389    0.00000   23    5 11.0000000    0.00000   100%   2.9 1165s
#  48889487 102642    0.00000   32    3 11.0000000    0.00000   100%   2.9 1171s
# ...

# %%
set_optimizer_attribute(model, "TimeLimit", 600)
#set_optimizer_attribute(model, "VarBranch", 0)
optimize!(model)
objective_value(model)
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 74 columns and 434 nonzeros
# Model fingerprint: 0x648e74a7
# Variable types: 14 continuous, 60 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+03, 2e+03]
# Presolved: 7 rows, 67 columns, 427 nonzeros
#
# Continuing optimization...
#
#  11681709 287739 infeasible   58        11.00000    0.00000   100%   3.0  240s
#  11893701 291392    0.00000   51    7   11.00000    0.00000   100%   3.0  245s
#  12113853 295770    0.00000   52    7   11.00000    0.00000   100%   3.0  250s
#  12339620 300293    0.00000   55    7   11.00000    0.00000   100%   3.0  255s
#  12566467 308834 infeasible   58        11.00000    0.00000   100%   3.0  260s
# ...

# %% [markdown]
# # VarBranch ablation experiment

# %% [markdown]
# Controls the branch variable selection strategy. The default -1 setting makes an automatic choice, depending on problem characteristics. Available alternatives are Pseudo Reduced Cost Branching (0), Pseudo Shadow Price Branching (1), Maximum Infeasibility Branching (2), and Strong Branching (3).

# %%
set_optimizer_attribute(model, "TimeLimit", 300)
set_optimizer_attribute(model, "VarBranch", 0)
optimize!(model)
objective_value(model)
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 74 columns and 434 nonzeros
# Model fingerprint: 0x648e74a7
# Variable types: 14 continuous, 60 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+03, 2e+03]
# Presolved: 7 rows, 67 columns, 427 nonzeros
#
# Continuing optimization...
#
#  65602720 389560    0.00000   40    3 11.0000000    0.00000   100%   2.9 1604s
#  65725485 450235    0.00000   42    5 11.0000000    0.00000   100%   2.9 1607s
#  65848250 197692    0.00000   56    5 11.0000000    0.00000   100%   2.9 1610s
#  66093780 440226    0.00000    7    8 11.0000000    0.00000   100%   2.9 1616s
#  66339310 114355    0.00000    5    1 11.0000000    0.00000   100%   2.9 1622s
# ...

# %%
set_optimizer_attribute(model, "TimeLimit", 300)
set_optimizer_attribute(model, "VarBranch", 1)
optimize!(model)
objective_value(model)
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 74 columns and 434 nonzeros
# Model fingerprint: 0x648e74a7
# Variable types: 14 continuous, 60 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+03, 2e+03]
# Presolved: 7 rows, 67 columns, 427 nonzeros
#
# Continuing optimization...
#
#  82867506 257450    0.00000   56    7 11.0000000    0.00000   100%   2.9 2055s
#  83113036 197994    0.00000   65    4 11.0000000    0.00000   100%   2.9 2061s
#  83358566 442837    0.00000    1    8 11.0000000    0.00000   100%   2.9 2067s
#  83481331 145124    0.00000    1    5 11.0000000    0.00000   100%   2.9 2070s
#  83726861 169647    0.00000   57    2 11.0000000    0.00000   100%   2.9 2076s
# ...

# %%
set_optimizer_attribute(model, "TimeLimit", 300)
set_optimizer_attribute(model, "VarBranch", 2)
optimize!(model)
objective_value(model)
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 74 columns and 434 nonzeros
# Model fingerprint: 0x648e74a7
# Variable types: 14 continuous, 60 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+03, 2e+03]
# Presolved: 7 rows, 67 columns, 427 nonzeros
#
# Continuing optimization...
#
#  94653337 147915    0.00000    8    3 11.0000000    0.00000   100%   2.9 2356s
#  94898867 37544    0.00000   28    6 11.0000000    0.00000   100%   2.9 2362s
#  95021632 48308    0.00000   37    5 11.0000000    0.00000   100%   2.9 2365s
#  95267162 426766    0.00000   36    7 11.0000000    0.00000   100%   2.9 2371s
#  95512692 256904    0.00000   31    2 11.0000000    0.00000   100%   2.9 2377s
# ...

# %%
set_optimizer_attribute(model, "TimeLimit", 300)
set_optimizer_attribute(model, "VarBranch", 3)
optimize!(model)
objective_value(model)
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 74 columns and 434 nonzeros
# Model fingerprint: 0x648e74a7
# Variable types: 14 continuous, 60 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+03, 2e+03]
# Presolved: 7 rows, 67 columns, 427 nonzeros
#
# Continuing optimization...
#
#  106607416 363809    0.00000   29    4 11.0000000    0.00000   100%   2.9 2660s
#
# Cutting planes:
#   Gomory: 1
#
# Explored 106607416 nodes (314289291 simplex iterations) in 12078.93 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 11 16 19 ... 52
#
# Time limit reached
# Best objective 1.100000000000e+01, best bound 0.000000000000e+00, gap 100.0000%
#
# User-callback calls 40654386, time in user-callback 7.37 sec
# ...

# %% [markdown]
# Global cut aggressiveness setting. Use value 0 to shut off cuts, 1 for moderate cut generation, 2 for aggressive cut generation, and 3 for very aggressive cut generation. This parameter is overridden by the parameters that control individual cut types

# %%
# Cuts ablation study

# %%
set_optimizer_attribute(model, "TimeLimit", 300)
set_optimizer_attribute(model, "Cuts", 0)
optimize!(model)
objective_value(model)
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 74 columns and 434 nonzeros
# Model fingerprint: 0x648e74a7
# Variable types: 14 continuous, 60 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+03, 2e+03]
# Presolved: 7 rows, 67 columns, 427 nonzeros
#
# Continuing optimization...
#
#  106730181 124645    0.00000    4    3 11.0000000    0.00000   100%   2.9 14740s
#  106975711 352133    0.00000   35    7 11.0000000    0.00000   100%   2.9 14745s
#  107221241 436782    0.00000   63    4 11.0000000    0.00000   100%   2.9 14751s
#  107466771 129395    0.00000    6    4 11.0000000    0.00000   100%   2.9 14757s
#  107589536 249472    0.00000   62    2 11.0000000    0.00000   100%   2.9 14760s
# ...

# %%
set_optimizer_attribute(model, "TimeLimit", 300)
set_optimizer_attribute(model, "Cuts", 1)
optimize!(model)
objective_value(model)
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 74 columns and 434 nonzeros
# Model fingerprint: 0x648e74a7
# Variable types: 14 continuous, 60 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+03, 2e+03]
# Presolved: 7 rows, 67 columns, 427 nonzeros
#
# Continuing optimization...
#
#  118179516 385058    0.00000    1    3 11.0000000    0.00000   100%   2.9 15041s
#  118425046 171087    0.00000   34    6 11.0000000    0.00000   100%   2.9 15047s
#  118547811 404908    0.00000   51    3 11.0000000    0.00000   100%   2.9 15050s
#  118793341 105761    0.00000   41    6 11.0000000    0.00000   100%   2.9 15056s
#  119038871 221637    0.00000   21    7 11.0000000    0.00000   100%   2.9 15062s
# ...

# %%
set_optimizer_attribute(model, "TimeLimit", 300)
set_optimizer_attribute(model, "Cuts", 2)
optimize!(model)
objective_value(model)
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 74 columns and 434 nonzeros
# Model fingerprint: 0x648e74a7
# Variable types: 14 continuous, 60 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+03, 2e+03]
# Presolved: 7 rows, 67 columns, 427 nonzeros
#
# Continuing optimization...
#
#  129965347 425374    0.00000   38    4 11.0000000    0.00000   100%   2.9 15343s
#  130088112 464733    0.00000   45    7 11.0000000    0.00000   100%   2.9 15347s
#  130333642 121388    0.00000   43    7 11.0000000    0.00000   100%   2.9 15352s
#  130456407 305407    0.00000   61    6 11.0000000    0.00000   100%   2.9 15355s
#  130701937 447561    0.00000   63    8 11.0000000    0.00000   100%   2.9 15361s
# ...

# %%
set_optimizer_attribute(model, "TimeLimit", 500)
set_optimizer_attribute(model, "Cuts", 3)
set_optimizer_attribute(model, "VarBranch", 2)
optimize!(model)
objective_value(model)
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 74 columns and 434 nonzeros
# Model fingerprint: 0x648e74a7
# Variable types: 14 continuous, 60 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+03, 2e+03]
# Presolved: 7 rows, 67 columns, 427 nonzeros
#
# Continuing optimization...
#
#  164818096 327596    0.00000   61    5 11.0000000    0.00000   100%   2.9 16253s
#  164940861 360630    0.00000   16    2 11.0000000    0.00000   100%   2.9 16255s
#  165186391 245038    0.00000   19    8 11.0000000    0.00000   100%   2.9 16261s
#  165431921 12711    0.00000   61    5 11.0000000    0.00000   100%   2.9 16267s
#  165554686 456609    0.00000   22    6 11.0000000    0.00000   100%   2.9 16270s
# ...

# %%
function solve(parameters::Vector=[])
    model = read_from_file("markshare2.mps")
    set_optimizer(model, Gurobi.Optimizer)
    set_optimizer_attributes(model, parameters...)
    #set_optimizer_attribute(model, "TimeLimit", 10)
    # Define optimization problem
    # Solve the problem
    solvetime = @elapsed optimize!(model)
    # Extract the number of nodes visited
    nodes = MOI.get(model, MOI.NodeCount())
    return nodes, solvetime
end
# Out:
# solve (generic function with 4 methods)

# %%
result = [solve(parameters = ["TimeLimit" => 10, "OutputFlag" => 0, "Cuts" => i]) for i = [0, 1, 2, 3]]
# Out:
# MethodError: no method matching solve(; parameters=["TimeLimit" => 10, "OutputFlag" => 0, "Cuts" => 0])
# Closest candidates are:
#   solve() at In[42]:1 got unsupported keyword argument "parameters"
#   solve(::Array{T,1} where T) at In[42]:1 got unsupported keyword argument "parameters"
#   solve(::Any) at In[31]:1 got unsupported keyword argument "parameters"
#   ...
#
# Stacktrace:
#  [1] (::var"#20#21")(::Int64) at ./none:0
#  [2] iterate at ./generator.jl:47 [inlined]
#  [3] collect(::Base.Generator{Array{Int64,1},var"#20#21"}) at ./array.jl:686
#  [4] top-level scope at In[43]:1
#  [5] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
using JuMP, Gurobi
using Plots, LinearAlgebra, Random

# %%
solve(parameters = ["OutputFlag" => 0, "Cuts" => 0])
# Out:
# MethodError: no method matching solve(; parameters=["OutputFlag" => 0, "Cuts" => 0])
# Closest candidates are:
#   solve() at In[32]:1 got unsupported keyword argument "parameters"
#   solve(::Array{T,1} where T) at In[32]:1 got unsupported keyword argument "parameters"
#   solve(::Any) at In[31]:1 got unsupported keyword argument "parameters"
#   ...
#
# Stacktrace:
#  [1] top-level scope at In[33]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
"Solve the optimization problem for n and k - pass a vector of parameters to the solver, return node count and time"
function odd_x_nodes(n::Int, k::Int; parameters::Vector=[])
    #model = Model(Gurobi.Optimizer)
    model = read_from_file("markshare2.mps")
    set_optimizer(model, Gurobi.Optimizer)
    set_optimizer_attributes(model, parameters...)
    # Define optimization problem
    #@variable(model, x[1:(n+1)], Bin)
    #@objective(model, Min, x[n+1])
    #@constraint(model, 2 * sum(x[i] for i = 1:n) + x[n + 1] == 2 * k + 1)
    # Solve the problem
    solvetime = @elapsed optimize!(model)
    # Extract the number of nodes visited
    nodes = MOI.get(model, MOI.NodeCount())
    return nodes, objective_value(model)
end
# Out:
# odd_x_nodes

# %%
result = [odd_x_nodes(20, 10, parameters = ["OutputFlag" => 0, "TimeLimit" => 180, "Cuts" => i]) for i = [-1, 0, 1, 2, 3]]
# Out:
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
# 5-element Array{Tuple{Float64,Float64},1}:
#  (7.312295e6, 16.000000000000014)
#  (1.077496e6, 19.99999999999996)
#  (934774.0, 34.999999999999986)
# ...

# %%
result5 = [odd_x_nodes(20, 10, parameters = ["OutputFlag" => 0, "TimeLimit" => 300, "Cuts" => i]) for i = [-1, 0, 1, 2, 3]]
# Out:
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
# 5-element Array{Tuple{Float64,Float64},1}:
#  (1.3778022e7, 12.0)
#  (1.350975e7, 19.99999999999996)
#  (9.217779e6, 10.999999999999991)
#  (3.500702e6, 20.0)
# ...

# %%
bar([-1, 0, 1, 2, 3], log10.(first.(result5)), yticks=([1, 2, 3, 4, 5, 6, 7], ["1e$i" for i = 1:7]),
    xticks = ([-1, 0, 1, 2, 3], ["Default", "No cuts", "Moderate", "Aggressive", "Very aggressive"]), label="Cutting strategy", ylabel="Nodes visited")

# %%
bar([0, 1, 2, 3, 4], (last.(result5)), fill="orange", linecolor="orange",
    xticks = ([0, 1, 2, 3, 4], ["Default", "No cuts", "Moderate", "Aggressive", "Very aggressive"]), label="", ylabel="Objective value")

# %%
bar([-1, 0, 1, 2, 3], log10.(first.(result)), yticks=([1, 2, 3, 4, 5, 6, 7], ["1e$i" for i = 1:7]),
    xticks = ([-1, 0, 1, 2, 3], ["Default", "No cuts", "Moderate", "Aggressive", "Very aggressive"]), label="Cutting strategy", ylabel="Nodes visited")

# %%
bar([0, 1, 2, 3, 4], (last.(result)), fill="orange", linecolor="orange",
    xticks = ([0, 1, 2, 3, 4], ["Default", "No cuts", "Moderate", "Aggressive", "Very aggressive"]), label="", ylabel="Objective value")

# %%
result3 = [odd_x_nodes(20, 10, parameters = ["OutputFlag" => 0, "TimeLimit" => 180, "Cuts" => 0, "VarBranch" => i]) for i = [-1, 0, 1, 2, 3]]
# Out:
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
# 5-element Array{Tuple{Float64,Float64},1}:
#  (9.694465e6, 19.99999999999996)
#  (8.662579e6, 17.000000000000085)
#  (8.386355e6, 16.0)
#  (9.666048e6, 15.0)
# ...

# %%
bar(collect(-1:3), (first.(result3)), 
    xticks = ([-1, 0, 1, 2, 3], ["-1: Default", "0: Reduced cost", "1: Shadow price", "2: Max infeasibility", "3: Strong"]),
    label="", ylabel="Nodes visited")

# %%
bar(collect(-1:3), (last.(result3)), fill="orange", linecolor="orange",
    xticks = ([-1, 0, 1, 2, 3], ["-1: Default", "0: Reduced cost", "1: Shadow price", "2: Max infeasibility", "3: Strong"]),
    label="", ylabel="Objective value")

# %%
result2 = [odd_x_nodes(20, 10, parameters = ["OutputFlag" => 0, "Cuts" => -1, "TimeLimit" => 20,
                                            "GomoryPasses" => j])
           for j = [0, 1, 4, 8, 16, 32]]
# Out:
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# ...

# %%
plot(log10.(first.(result2))', label=permutedims(["FlowCoverCuts = $i" for i = 0:2]), lw=4, ls=:auto,
     xticks = (collect(1:8), [0, 1, 2, 4, 8, 16, 32, 64]), xlabel="GomoryPasses",
     yticks=([1, 2, 3, 4, 5], ["1e$i" for i = 1:5]), ylabel="Nodes visited")

# %%
result4 = [odd_x_nodes(20, 10, parameters = ["OutputFlag" => 0, "TimeLimit" => i]) for i = [200, 350, 500, 650]]
# Out:
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
# 4-element Array{Tuple{Float64,Float64},1}:
#  (9.94178e6, 12.0)
#  (1.6285659e7, 12.0)
#  (2.2342188e7, 12.0)
#  (2.8676054e7, 12.0)

# %%
bar(collect(0:3), (first.(result4)),
    xticks = ([0, 1, 2, 3], ["200", "350", "500", "650"]),
    label="", ylabel="Nodes visited")

# %%
bar(collect(0:3), (last.(result4)),
    xticks = ([0, 1, 2, 3], ["200", "350", "500", "650"]),
    label="", ylabel="Objective Value")

# %%
model = read_from_file("markshare2.mps")
set_optimizer(model, Gurobi.Optimizer)
set_optimizer_attribute(model, "TimeLimit", 600)
set_optimizer_attribute(model, "Cuts", 1)
set_optimizer_attribute(model, "VarBranch", 1)
set_optimizer_attribute(model, "Heuristics", 0)
set_optimizer_attribute(model, "Presolve", 1)
set_optimizer_attribute(model, "Seed", 6)
optimize!(model)
objective_value(model)
# Out:
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 74 columns and 434 nonzeros
# Model fingerprint: 0x648e74a7
# Variable types: 14 continuous, 60 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+03, 2e+03]
# Presolve removed 0 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 67 columns, 427 nonzeros
# Variable types: 0 continuous, 67 integer (60 binary)
#
# Root relaxation: objective 0.000000e+00, 19 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# ...

# %%
model = read_from_file("markshare2.mps")
set_optimizer(model, Gurobi.Optimizer)
set_optimizer_attribute(model, "TimeLimit", 600)
set_optimizer_attribute(model, "Cuts", 1)
set_optimizer_attribute(model, "VarBranch", 2)
set_optimizer_attribute(model, "Heuristics", 0)
set_optimizer_attribute(model, "Presolve", 1)
set_optimizer_attribute(model, "Seed", 6)
optimize!(model)
objective_value(model)
# Out:
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-04-27
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 74 columns and 434 nonzeros
# Model fingerprint: 0x648e74a7
# Variable types: 14 continuous, 60 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+03, 2e+03]
# Presolve removed 0 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 67 columns, 427 nonzeros
# Variable types: 0 continuous, 67 integer (60 binary)
#
# Root relaxation: objective 0.000000e+00, 19 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# ...
