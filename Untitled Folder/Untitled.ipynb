# %%
from PIL import Image

# %%
im = Image.open('../../Downloads/firedanger_MMdsMC6cLIkmYMwj3lPl/emodis_wlfp_data_20210422_20210422.tiff')

# %%
im
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1217     try:
# -> 1218         rawmode, mode = _OUTMODES[mode]
#    1219     except KeyError as e:
#
# KeyError: 'F'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/PIL/Image.py in _repr_png_(self)
#     673         try:
# --> 674             self.save(b, "PNG")
#     675         except Exception as e:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2163         try:
# ...

# %%
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=P size=1750x1000 at 0x7F98E5C493D0>

# %%
#import numpy as np
imarray = np.array(im)

# %%
im2 = np.where(imarray<0, 0, imarray)

# %%
import matplotlib.pyplot as plt
plt.imshow(im2)

# %%
im2.shape
# Out:
# (95, 96)

# %%
np.savetxt('LA_2021_04_22.csv', im2[:90,:90])
